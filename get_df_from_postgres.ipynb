# %%
import pandas as pd
import psycopg2 as pg

# %%
# Выгрузка таблицы 'd_agreement'.
conn = pg.connect(dbname='module_6', user='postgres', password='pigul6380050', host='localhost')

query = '''
    SELECT * FROM d_agreement;
    '''

d_agreement_df = pd.read_sql(query, conn)
d_agreement_df.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2712\386888808.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   d_agreement_df = pd.read_sql(query, conn)
#    agreement_rk    id_client  target
# 0    59910150.0  106804370.0     0.0
# 1    59910230.0  106804371.0     0.0
# 2    59910525.0  106804372.0     0.0
# 3    59910803.0  106804373.0     0.0
# 4    59911781.0  106804374.0     0.0

# %%
# Сохранение таблицы 'd_agreement' в csv-файл.
d_agreement_df.to_csv('data/6.8 agreement_df.csv', index=False)

# %%
# Выгрузка таблицы 'd_clients'.
conn = pg.connect(dbname='module_6', user='postgres', password='pigul6380050', host='localhost')

query = '''
    SELECT * FROM d_clients;
    '''

d_clients_df = pd.read_sql(query, conn)
d_clients_df.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2712\3340368831.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   d_clients_df = pd.read_sql(query, conn)
#             id   age  gender            education      marital_status  \
# 0  106805103.0  42.0     1.0              Среднее  Не состоял в браке
# 1  106809308.0  28.0     1.0  Среднее специальное      Состою в браке
# 2  106805867.0  64.0     0.0  Среднее специальное      Состою в браке
# 3  106808779.0  54.0     1.0  Среднее специальное      Состою в браке
# 4  106814289.0  26.0     0.0  Среднее специальное      Состою в браке
#
#    child_total  dependants  socstatus_work_fl  socstatus_pens_fl  \
# 0          1.0         0.0                2.0                1.0
# 1          1.0         1.0                2.0                1.0
# ...

# %%
# Сохранение таблицы 'd_clients' в csv-файл.
d_clients_df.to_csv('data/6.8 clients_df.csv', index=False)

# %%
# Выгрузка таблицы 'd_salary'.
conn = pg.connect(dbname='module_6', user='postgres', password='pigul6380050', host='localhost')

query = '''
    SELECT * FROM d_salary;
    '''

d_salary_df = pd.read_sql(query, conn)
d_salary_df.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2712\193017221.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   d_salary_df = pd.read_sql(query, conn)
#             family_income  personal_income    id_client
# 0  от 20000 до 50000 руб.          20000.0  106809321.0
# 1  от 20000 до 50000 руб.          14000.0  106815561.0
# 2  от 10000 до 20000 руб.          15000.0  106811521.0
# 3  от 20000 до 50000 руб.          20000.0  106811252.0
# 4  от 20000 до 50000 руб.          25000.0  106808620.0

# %%
# Сохранение таблицы 'd_salary' в csv-файл.
d_salary_df.to_csv('data/6.8 salary_df.csv', index=False)

# %%
# Выгрузка таблицы 'd_loan'.
conn = pg.connect(dbname='module_6', user='postgres', password='pigul6380050', host='localhost')

query = '''
    SELECT * FROM d_loan;
    '''

d_loan_df = pd.read_sql(query, conn)
d_loan_df.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2712\1175410808.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   d_loan_df = pd.read_sql(query, conn)
#         id_loan    id_client
# 0  1.753791e+09  106804370.0
# 1  1.753791e+09  106804371.0
# 2  1.753791e+09  106804372.0
# 3  1.753791e+09  106804372.0
# 4  1.753791e+09  106804373.0

# %%
# Сохранение таблицы 'd_loan' в csv-файл.
d_loan_df.to_csv('data/6.8 loan_df.csv', index=False)

# %%
# Выгрузка таблицы 'd_close_loan'.
conn = pg.connect(dbname='module_6', user='postgres', password='pigul6380050', host='localhost')

query = '''
    SELECT * FROM d_close_loan;
    '''

d_close_loan_df = pd.read_sql(query, conn)
d_close_loan_df.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2712\1537171573.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   d_close_loan_df = pd.read_sql(query, conn)
#         id_loan  closed_fl
# 0  1.753791e+09        1.0
# 1  1.753791e+09        1.0
# 2  1.753791e+09        1.0
# 3  1.753791e+09        0.0
# 4  1.753791e+09        1.0

# %%
# Сохранение таблицы 'd_close_loan' в csv-файл.
d_close_loan_df.to_csv('data/6.8 close_loan_df.csv', index=False)
